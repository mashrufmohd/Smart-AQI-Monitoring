# %% [markdown]
# # 01 - Data Exploration
# This notebook explores the air quality dataset, its structure, and basic statistics.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
# Load the dataset
df = pd.read_csv('../data/processed_aqi.csv')

# %%
# Explore the dataset
print("Shape of Dataset:", df.shape)
print("\nFirst 5 Rows:\n", df.head())
print("\n--- Dataset Info ---")
print(df.info())
print("\n--- Statistical Summary ---")
print(df.describe())
print("\n--- Missing Values ---")
print(df.isnull().sum())
# Out:
# Shape of Dataset: (3, 12)
#
# First 5 Rows:
#           Date   City  PM2.5  PM10  NO2  SO2   CO  O3  Benzene  Toluene  \
# 0  2020-01-01  Delhi    120   200   40   10  1.2  30        5        3
# 1  2020-01-02  Delhi    110   180   38    9  1.1  28        4        2
# 2  2020-01-03  Delhi    130   210   42   11  1.3  32        6        3
#
#    Xylene AQI_Bucket
# 0       1   Moderate
# 1       1       Good
# 2       1       Poor
#
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        3 non-null      object
#  1   City        3 non-null      object
#  2   PM2.5       3 non-null      int64
#  3   PM10        3 non-null      int64
#  4   NO2         3 non-null      int64
#  5   SO2         3 non-null      int64
#  6   CO          3 non-null      float64
#  7   O3          3 non-null      int64
#  8   Benzene     3 non-null      int64
#  9   Toluene     3 non-null      int64
#  10  Xylene      3 non-null      int64
#  11  AQI_Bucket  3 non-null      object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 420.0+ bytes
# None
#
# --- Statistical Summary ---
#        PM2.5        PM10   NO2   SO2    CO    O3  Benzene   Toluene  Xylene
# count    3.0    3.000000   3.0   3.0  3.00   3.0      3.0  3.000000     3.0
# mean   120.0  196.666667  40.0  10.0  1.20  30.0      5.0  2.666667     1.0
# std     10.0   15.275252   2.0   1.0  0.10   2.0      1.0  0.577350     0.0
# min    110.0  180.000000  38.0   9.0  1.10  28.0      4.0  2.000000     1.0
# 25%    115.0  190.000000  39.0   9.5  1.15  29.0      4.5  2.500000     1.0
# 50%    120.0  200.000000  40.0  10.0  1.20  30.0      5.0  3.000000     1.0
# 75%    125.0  205.000000  41.0  10.5  1.25  31.0      5.5  3.000000     1.0
# max    130.0  210.000000  42.0  11.0  1.30  32.0      6.0  3.000000     1.0
#
# --- Missing Values ---
# Date          0
# City          0
# PM2.5         0
# PM10          0
# NO2           0
# SO2           0
# CO            0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI_Bucket    0
# dtype: int64

# %%
# AQI_Bucket distribution and plot
if 'AQI_Bucket' in df.columns:
    print("\nAQI_Bucket Value Counts:\n", df['AQI_Bucket'].value_counts())
    plt.figure(figsize=(7,4))
    sns.countplot(data=df, x="AQI_Bucket", palette="coolwarm", order=df["AQI_Bucket"].value_counts().index)
    plt.title("Distribution of AQI Categories")
    plt.xticks(rotation=30)
    plt.show()
# Out:
# AQI_Bucket Value Counts:
#  AQI_Bucket
# Moderate    1
# Good        1
# Poor        1
# Name: count, dtype: int64
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_13476\649995376.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="AQI_Bucket", palette="coolwarm", order=df["AQI_Bucket"].value_counts().index)

# %%
# Correlation Heatmap for pollutants
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="YlOrRd", fmt=".2f")
plt.title("Correlation Heatmap of Pollutants & AQI")
plt.show()

# %% [markdown]
# ✅ Data exploration completed. Ready for preprocessing.

# %% [markdown]
# ➡️ Proceed to 02_preprocessing.ipynb for data cleaning and feature engineering.
